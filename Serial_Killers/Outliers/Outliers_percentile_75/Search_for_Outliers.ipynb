# %% [markdown]
# # Search for Outliers

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns


jtplot.style(figsize=(15, 9))

# %%
from outl_75 import *

# %%
d, cases = get_cases_above_75(['Year', 'State'], data_params={'Solved': 'No', 'VicSex': 'Female'})

# %%
d, cases = get_cases_above_75('Year', data_params={'Solved': 'No', 'VicSex': 'Female', 'State': 'Texas'})

# %%
d, cases = get_cases_above_75('State', data_params={'Solved': 'No', 'VicSex': 'Female', 'Year': 1986})
