# %% [markdown]
# # Roadmap of Outliers

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import pickle as pk

from jupyterthemes import jtplot

jtplot.style(figsize=(15, 9))

# %% [markdown]
# - 75 Procentile
#     - by Year, State
#         - VicSex: All    / {All, Solved, Unsolved}
#         - VicSex: Female / {All, Solved, Unsolved}
#         - VicSex: Male   / {All, Solved, Unsolved}
#
#     - by Weapon, State
#         - VicSex: All    / {All, Solved, Unsolved}
#         - VicSex: Female / {All, Solved, Unsolved}
#         - VicSex: Male   / {All, Solved, Unsolved}
#
#     - by Circumstance, State
#         - VicSex: All    / {All, Solved, Unsolved}
#         - VicSex: Female / {All, Solved, Unsolved}
#         - VicSex: Male   / {All, Solved, Unsolved}
